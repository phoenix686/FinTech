# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:

        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
apple=yf.download('AAPL',start='2010-01-01',end='2021-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.470740
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.481929
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.378824
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.367032
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.409362
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  129.514465
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.146637
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.360519
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.231903
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.221100
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
ticker=['SPY','AAPL','KO']
stocks=yf.download(ticker,start='2010-01-01',end='2021-01-01')
stocks
# Out:
# [*********************100%%**********************]  3 of 3 completed
# Price        Adj Close                              Close             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.470740  18.498020   87.129944    7.643214  28.520000
# 2010-01-05    6.481929  18.274246   87.360580    7.656429  28.174999
# 2010-01-06    6.378824  18.267767   87.422104    7.534643  28.165001
# 2010-01-07    6.367032  18.222368   87.791107    7.520714  28.094999
# 2010-01-08    6.409362  17.885092   88.083275    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.514465  48.779106  352.968018  131.970001  53.439999
# 2020-12-28  134.146637  49.436302  356.000366  136.690002  54.160000
# 2020-12-29  132.360519  49.408924  355.321167  134.869995  54.130001
# 2020-12-30  131.231903  49.691891  355.828094  133.720001  54.439999
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2769 entries, 2010-01-04 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2769 non-null   float64
#  1   (Adj Close, KO)    2769 non-null   float64
#  2   (Adj Close, SPY)   2769 non-null   float64
#  3   (Close, AAPL)      2769 non-null   float64
#  4   (Close, KO)        2769 non-null   float64
#  5   (Close, SPY)       2769 non-null   float64
#  6   (High, AAPL)       2769 non-null   float64
#  7   (High, KO)         2769 non-null   float64
#  8   (High, SPY)        2769 non-null   float64
#  9   (Low, AAPL)        2769 non-null   float64
#  10  (Low, KO)          2769 non-null   float64
#  11  (Low, SPY)         2769 non-null   float64
#  12  (Open, AAPL)       2769 non-null   float64
#  13  (Open, KO)         2769 non-null   float64
#  14  (Open, SPY)        2769 non-null   float64
# ...

# %%
stocks.to_csv('stocks.csv')

# %%
stocks=pd.read_csv('stocks.csv')
stocks
# Out:
#            Price           Adj Close         Adj Close.1        Adj Close.2  \
# 0         Ticker                AAPL                  KO                SPY
# 1           Date                 NaN                 NaN                NaN
# 2     2010-01-04   6.470739841461182   18.49802017211914  87.12994384765625
# 3     2010-01-05   6.481928825378418  18.274246215820312  87.36058044433594
# 4     2010-01-06   6.378824234008789   18.26776695251465  87.42210388183594
# ...          ...                 ...                 ...                ...
# 2766  2020-12-24  129.51446533203125   48.77910614013672   352.968017578125
# 2767  2020-12-28  134.14663696289062  49.436302185058594  356.0003662109375
# 2768  2020-12-29   132.3605194091797    49.4089241027832  355.3211669921875
# 2769  2020-12-30  131.23190307617188  49.691890716552734  355.8280944824219
# 2770  2020-12-31  130.22109985351562  50.057003021240234  357.6360168457031
#
# ...

# %%
stocks=pd.read_csv('stocks.csv',header=[0,1]) #making header
stocks
# Out:
#            Price   Adj Close                              Close             \
#           Ticker        AAPL         KO         SPY        AAPL         KO
# 0           Date         NaN        NaN         NaN         NaN        NaN
# 1     2010-01-04    6.470740  18.498020   87.129944    7.643214  28.520000
# 2     2010-01-05    6.481929  18.274246   87.360580    7.656429  28.174999
# 3     2010-01-06    6.378824  18.267767   87.422104    7.534643  28.165001
# 4     2010-01-07    6.367032  18.222368   87.791107    7.520714  28.094999
# ...          ...         ...        ...         ...         ...        ...
# 2765  2020-12-24  129.514465  48.779106  352.968018  131.970001  53.439999
# 2766  2020-12-28  134.146637  49.436302  356.000366  136.690002  54.160000
# 2767  2020-12-29  132.360519  49.408924  355.321167  134.869995  54.130001
# 2768  2020-12-30  131.231903  49.691891  355.828094  133.720001  54.439999
# ...

# %%
stocks=pd.read_csv('stocks.csv',header=[0,1],index_col=[0]) #index 
stocks
# Out:
# Price        Adj Close                              Close             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.470740  18.498020   87.129944    7.643214  28.520000
# 2010-01-05    6.481929  18.274246   87.360580    7.656429  28.174999
# 2010-01-06    6.378824  18.267767   87.422104    7.534643  28.165001
# 2010-01-07    6.367032  18.222368   87.791107    7.520714  28.094999
# 2010-01-08    6.409362  17.885092   88.083275    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.514465  48.779106  352.968018  131.970001  53.439999
# 2020-12-28  134.146637  49.436302  356.000366  136.690002  54.160000
# 2020-12-29  132.360519  49.408924  355.321167  134.869995  54.130001
# 2020-12-30  131.231903  49.691891  355.828094  133.720001  54.439999
# 2020-12-31  130.221100  50.057003  357.636017  132.690002  54.840000
#
# ...

# %%
stocks=pd.read_csv('stocks.csv',header=[0,1],index_col=[0],parse_dates=[0]) #index 
stocks
# Out:
# Price        Adj Close                              Close             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.470740  18.498020   87.129944    7.643214  28.520000
# 2010-01-05    6.481929  18.274246   87.360580    7.656429  28.174999
# 2010-01-06    6.378824  18.267767   87.422104    7.534643  28.165001
# 2010-01-07    6.367032  18.222368   87.791107    7.520714  28.094999
# 2010-01-08    6.409362  17.885092   88.083275    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.514465  48.779106  352.968018  131.970001  53.439999
# 2020-12-28  134.146637  49.436302  356.000366  136.690002  54.160000
# 2020-12-29  132.360519  49.408924  355.321167  134.869995  54.130001
# 2020-12-30  131.231903  49.691891  355.828094  133.720001  54.439999
# 2020-12-31  130.221100  50.057003  357.636017  132.690002  54.840000
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
#convert multiindex to one tuple
stocks.columns=stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.470740        18.498020         87.129944
# 2010-01-05           6.481929        18.274246         87.360580
# 2010-01-06           6.378824        18.267767         87.422104
# 2010-01-07           6.367032        18.222368         87.791107
# 2010-01-08           6.409362        17.885092         88.083275
# ...                       ...              ...               ...
# 2020-12-24         129.514465        48.779106        352.968018
# 2020-12-28         134.146637        49.436302        356.000366
# 2020-12-29         132.360519        49.408924        355.321167
# 2020-12-30         131.231903        49.691891        355.828094
# 2020-12-31         130.221100        50.057003        357.636017
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# ...

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.470740  18.498020   87.129944    7.643214  28.520000
# 2010-01-05    6.481929  18.274246   87.360580    7.656429  28.174999
# 2010-01-06    6.378824  18.267767   87.422104    7.534643  28.165001
# 2010-01-07    6.367032  18.222368   87.791107    7.520714  28.094999
# 2010-01-08    6.409362  17.885092   88.083275    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.514465  48.779106  352.968018  131.970001  53.439999
# 2020-12-28  134.146637  49.436302  356.000366  136.690002  54.160000
# 2020-12-29  132.360519  49.408924  355.321167  134.869995  54.130001
# 2020-12-30  131.231903  49.691891  355.828094  133.720001  54.439999
# 2020-12-31  130.221100  50.057003  357.636017  132.690002  54.840000
#
# ...

# %%
close=stocks.loc[:,'Close'].copy()
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
# %matplotlib inline
plt.style.use('seaborn')
close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_33/398605766.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.AAPL.div(close.iloc[0,0])
# Out:
# Date
# 2010-01-04     1.000000
# 2010-01-05     1.001729
# 2010-01-06     0.985795
# 2010-01-07     0.983973
# 2010-01-08     0.990514
#                 ...
# 2020-12-24    17.266296
# 2020-12-28    17.883838
# 2020-12-29    17.645717
# 2020-12-30    17.495258
# 2020-12-31    17.360498
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2010-01-04     100.000000
# 2010-01-05     100.172893
# 2010-01-06      98.579511
# 2010-01-07      98.397266
# 2010-01-08      99.051443
#                  ...
# 2020-12-24    1726.629626
# 2020-12-28    1788.383766
# 2020-12-29    1764.571699
# 2020-12-30    1749.525753
# 2020-12-31    1736.049763
# Name: AAPL, Length: 2769, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# KO       28.520000
# SPY     113.330002
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2020-12-24  1726.629626  187.377271  325.597806
# 2020-12-28  1788.383766  189.901820  328.394959
# 2020-12-29  1764.571699  189.796635  327.768451
# 2020-12-30  1749.525753  190.883583  328.236111
# 2020-12-31  1736.049763  192.286112  329.903820
#
# [2769 rows x 3 columns]

# %%
normclose=close.div(close.iloc[0]).mul(100)
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl=close.AAPL.copy().to_frame()
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
#shifting
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
aapl['lag1']=aapl.shift(periods=1)
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
aapl['Diff']=aapl.AAPL.sub(aapl.lag1) #diff
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2769 rows x 3 columns]

# %%
# % change
aapl['% change']=aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265
#
# [2769 rows x 4 columns]

# %%
aapl['diff2']=aapl.AAPL.diff(periods=1)
aapl
# Out:
#                   AAPL        lag1      Diff  % change     diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999
#
# [2769 rows x 5 columns]

# %%
#simpler method
aapl['% change2']=aapl.AAPL.pct_change(periods=1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % change     diff2  % change2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN        NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215   0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786  -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929  -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000   0.664833
# ...                ...         ...       ...       ...       ...        ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995   0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001   3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007  -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994  -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999  -0.770265
#
# [2769 rows x 6 columns]

# %%
aapl.drop(['diff2','lag1','Diff','% change'],axis=1,inplace=True)

# %%
aapl
# Out:
#                   AAPL  % change2
# Date
# 2010-01-04    7.643214        NaN
# 2010-01-05    7.656429   0.172893
# 2010-01-06    7.534643  -1.590632
# 2010-01-07    7.520714  -0.184871
# 2010-01-08    7.570714   0.664833
# ...                ...        ...
# 2020-12-24  131.970001   0.771224
# 2020-12-28  136.690002   3.576571
# 2020-12-29  134.869995  -1.331485
# 2020-12-30  133.720001  -0.852668
# 2020-12-31  132.690002  -0.770265
#
# [2769 rows x 2 columns]

# %%
aapl.rename(columns={'% change2':'change'},inplace=True)
aapl
# Out:
#                   AAPL    change
# Date
# 2010-01-04    7.643214       NaN
# 2010-01-05    7.656429  0.172893
# 2010-01-06    7.534643 -1.590632
# 2010-01-07    7.520714 -0.184871
# 2010-01-08    7.570714  0.664833
# ...                ...       ...
# 2020-12-24  131.970001  0.771224
# 2020-12-28  136.690002  3.576571
# 2020-12-29  134.869995 -1.331485
# 2020-12-30  133.720001 -0.852668
# 2020-12-31  132.690002 -0.770265
#
# [2769 rows x 2 columns]

# %%
aapl.AAPL.resample('M').last() #end of the month
# Out:
# /tmp/ipykernel_33/131391763.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   aapl.AAPL.resample('M').last() #end of the month
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: ME, Name: AAPL, Length: 132, dtype: float64

# %%
aapl.AAPL.resample('BM').last().pct_change(periods=1).mul(100) #last business day
# Out:
# /tmp/ipykernel_33/2634277487.py:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   aapl.AAPL.resample('BM').last().pct_change(periods=1).mul(100) #last business day
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BME, Name: AAPL, Length: 132, dtype: float64

# %%
aapl.drop(['change'],axis=1,inplace=True)
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
ret=aapl.pct_change().dropna()
ret
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# ...              ...
# 2020-12-24  0.007712
# 2020-12-28  0.035766
# 2020-12-29 -0.013315
# 2020-12-30 -0.008527
# 2020-12-31 -0.007703
#
# [2768 rows x 1 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2768 entries, 2010-01-05 to 2020-12-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2768 non-null   float64
# dtypes: float64(1)
# memory usage: 43.2 KB

# %%
ret.plot(kind='hist',figsize=(12,8),bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
daily_mean_return=ret.mean()
daily_mean_return
# Out:
# AAPL    0.001191
# dtype: float64

# %%
ver_daily=ret.var()
ver_daily
# Out:
# AAPL    0.000318
# dtype: float64

# %%
std_daily=np.sqrt(ver_daily)
std_daily
# Out:
# AAPL    0.017843
# dtype: float64

# %%
#or
ret.std()
# Out:
# AAPL    0.017843
# dtype: float64

# %%
annual_mean_ret=daily_mean_return*252
annual_mean_ret
# Out:
# AAPL    0.300134
# dtype: float64

# %%
annual_var_ret=ver_daily*252
annual_var_ret
# Out:
# AAPL    0.080226
# dtype: float64

# %%
annual_std_return=np.sqrt(annual_var_ret)
annual_std_return
# Out:
# AAPL    0.283242
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL    0.283242
# dtype: float64

# %%
ticker=['SPY','AAPL','KO','IBM','DIS','MSFT']
stocks=yf.download(ticker,start='2010-01-01',end='2021-01-01')
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
stocks
# Out:
# Price        Adj Close                                                 \
# Ticker            AAPL         DIS         IBM         KO        MSFT
# Date
# 2010-01-04    6.470740   27.843180   76.767433  18.498020   23.431593
# 2010-01-05    6.481929   27.773720   75.840073  18.274246   23.439159
# 2010-01-06    6.378824   27.626127   75.347412  18.267767   23.295319
# 2010-01-07    6.367032   27.634809   75.086594  18.222368   23.053045
# 2010-01-08    6.409362   27.678219   75.840073  17.885092   23.212032
# ...                ...         ...         ...        ...         ...
# 2020-12-24  129.514465  173.165634  102.086243  48.779106  216.523865
# 2020-12-28  134.146637  178.278976  102.192680  49.436302  218.672119
# 2020-12-29  132.360519  176.724045  101.357574  49.408924  217.884735
# 2020-12-30  131.231903  180.581467  101.799667  49.691891  215.483765
# 2020-12-31  130.221100  180.591431  103.060509  50.057003  216.203079
#
# ...

# %%
close=stocks.loc[:,'Close'].copy()
normclose=close.div(close.iloc[0]).mul(100)
normclose.plot(figsize=(15,8),fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %%
ret=close.pct_change().dropna()
ret
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338  0.005081
#
# [2768 rows x 6 columns]

# %%
ret.describe()
# Out:
# Ticker         AAPL          DIS          IBM           KO         MSFT  \
# count   2768.000000  2768.000000  2768.000000  2768.000000  2768.000000
# mean       0.001191     0.000749     0.000082     0.000298     0.000841
# std        0.017843     0.015717     0.014132     0.011088     0.016012
# min       -0.128647    -0.129846    -0.128507    -0.096725    -0.147390
# 25%       -0.007123    -0.006210    -0.006321    -0.004698    -0.006939
# 50%        0.000903     0.000629     0.000287     0.000438     0.000654
# 75%        0.010379     0.007901     0.006743     0.005706     0.008636
# max        0.119808     0.144123     0.113010     0.064796     0.142169
#
# Ticker          SPY
# count   2768.000000
# mean       0.000491
# std        0.010909
# min       -0.109424
# 25%       -0.003532
# 50%        0.000637
# 75%        0.005421
# max        0.090603

# %%
summary=ret.describe().loc[['mean','std'],:].T
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001191  0.017843
# DIS     0.000749  0.015717
# IBM     0.000082  0.014132
# KO      0.000298  0.011088
# MSFT    0.000841  0.016012
# SPY     0.000491  0.010909

# %%
summary['mean']=summary['mean']*252
summary['std']=summary['std']*np.sqrt(252)
summary #comparing risk-reward for all stocks
# Out:
#             mean       std
# Ticker
# AAPL    0.300134  0.283242
# DIS     0.188696  0.249504
# IBM     0.020648  0.224345
# KO      0.075091  0.176009
# MSFT    0.211915  0.254185
# SPY     0.123754  0.173170

# %%
summary.plot.scatter(x='std',y='mean',figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,'std']+0.002,summary.loc[i,'mean']+0.002),size=15)
plt.xlabel('Annual risk(std)',fontsize=15)
plt.ylabel('Annual return',fontsize=15)
plt.title('Risk-return graph',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Risk-return graph')

# %% [markdown]
# - This shows that apple stock has high risk and gives high reward as well
# - ibm despite having high risk has low rewards and it not a good choice
# - spy has lower risk and higher rewards compared to ko and is a good choice
# - though disney has lower risk,microsoft has negigibly more risk but higher reward and is preferred over disney

# %%
# correlation and covariance

# %%
ret
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338  0.005081
#
# [2768 rows x 6 columns]

# %%
ret.cov()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    0.000318  0.000115  0.000110  0.000067  0.000158  0.000128
# DIS     0.000115  0.000247  0.000111  0.000085  0.000121  0.000121
# IBM     0.000110  0.000111  0.000200  0.000079  0.000121  0.000108
# KO      0.000067  0.000085  0.000079  0.000123  0.000076  0.000077
# MSFT    0.000158  0.000121  0.000121  0.000076  0.000256  0.000130
# SPY     0.000128  0.000121  0.000108  0.000077  0.000130  0.000119

# %%
ret.corr()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    1.000000  0.408513  0.436100  0.339213  0.554051  0.659557
# DIS     0.408513  1.000000  0.497775  0.486514  0.480457  0.706726
# IBM     0.436100  0.497775  1.000000  0.502436  0.533130  0.703342
# KO      0.339213  0.486514  0.502436  1.000000  0.429749  0.639324
# MSFT    0.554051  0.480457  0.533130  0.429749  1.000000  0.744601
# SPY     0.659557  0.706726  0.703342  0.639324  0.744601  1.000000

# %%
import seaborn as sns
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap='Reds',annot=True,annot_kws={'size':15},vmax=0.6)
# Out:
# <Axes: xlabel='Ticker', ylabel='Ticker'>

# %% [markdown]
# It's best to choose stocks that are highly uncorrelated in your portfolio such as apple and coca-cola,even if the price of one of them falls the other remains unaffected

# %% [markdown]
# # simple returns and log returns

# %%
df=pd.DataFrame(index=[2016,2017,2018],data=[100,50,95],columns=['Price'])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturn=df.pct_change().dropna()
simplereturn
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturn.mean() #But actually 100*1.2*1.2 =144
# Out:
# Price    0.2
# dtype: float64

# %%
#mean returns are misleading,we use log returns

logreturns=np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2) #correct last value using log
# Out:
# Price    95.0
# dtype: float64

# %%
SPY=yf.download('SPY')
SPY
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   24.840677
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.017365
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.070358
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.335390
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.441380
# ...                ...         ...         ...         ...         ...
# 2024-02-23  509.269989  510.130005  507.100006  507.850006  507.850006
# 2024-02-26  508.299988  508.750000  505.859985  505.989990  505.989990
# 2024-02-27  506.700012  507.160004  504.750000  506.929993  506.929993
# 2024-02-28  505.329987  506.859985  504.959991  506.260010  506.260010
# 2024-02-29  508.070007  509.739990  505.350006  508.079987  508.079987
#
#               Volume
# Date
# ...

# %%
spy=SPY.Close.to_frame()
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-02-23  507.850006
# 2024-02-26  505.989990
# 2024-02-27  506.929993
# 2024-02-28  506.260010
# 2024-02-29  508.079987
#
# [7827 rows x 1 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %%
spy_roll=spy.rolling(window=10)
spy_roll
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
spy_roll.mean().head(15) #first 10 are NaN as it takes 10 values to perform avg
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy_roll.median().head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.765625
# 1993-02-12  44.765625
# 1993-02-16  44.765625
# 1993-02-17  44.765625
# 1993-02-18  44.687500
# 1993-02-19  44.625000

# %%
spy_roll.max().head(15)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04       NaN
# 1993-02-05       NaN
# 1993-02-08       NaN
# 1993-02-09       NaN
# 1993-02-10       NaN
# 1993-02-11  45.00000
# 1993-02-12  45.00000
# 1993-02-16  45.00000
# 1993-02-17  45.00000
# 1993-02-18  45.00000
# 1993-02-19  44.96875

# %%
spy['sma50']=spy.rolling(window=50,min_periods=50).mean()
spy
# Out:
#                  Close       sma50
# Date
# 1993-01-29   43.937500         NaN
# 1993-02-01   44.250000         NaN
# 1993-02-02   44.343750         NaN
# 1993-02-03   44.812500         NaN
# 1993-02-04   45.000000         NaN
# ...                ...         ...
# 2024-02-23  507.850006  483.374402
# 2024-02-26  505.989990  484.212202
# 2024-02-27  506.929993  484.940802
# 2024-02-28  506.260010  485.625802
# 2024-02-29  508.079987  486.400802
#
# [7827 rows x 2 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %%
spy['sma200']=spy['Close'].rolling(window=200,min_periods=200).mean()
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %%
spy['ema100']=spy['Close'].ewm(span=100,min_periods=100).mean()
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc='upper left',fontsize=15)
plt.show()

# %%
spy['day']=spy.index.day_name()
spy['quarter']=spy.index.quarter
spy
# Out:
#                  Close       sma50      sma200      ema100        day  quarter
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday        1
# ...                ...         ...         ...         ...        ...      ...
# 2024-02-23  507.850006  483.374402  449.298901  469.296823     Friday        1
# 2024-02-26  505.989990  484.212202  449.774201  470.023421     Monday        1
# 2024-02-27  506.929993  484.940802  450.244601  470.754244    Tuesday        1
# 2024-02-28  506.260010  485.625802  450.715251  471.457329  Wednesday        1
# 2024-02-29  508.079987  486.400802  451.197701  472.182530   Thursday        1
#
# ...

# %%
SPY=yf.download('SPY')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy=SPY.Close.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-02-23  507.850006
# 2024-02-26  505.989990
# 2024-02-27  506.929993
# 2024-02-28  506.260010
# 2024-02-29  508.079987
#
# [7827 rows x 1 columns]

# %%
all_days=pd.date_range(start='2010-12-31',end='2020-01-01',freq='D')
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-02-23  507.850006
# 2024-02-26  505.989990
# 2024-02-27  506.929993
# 2024-02-28  506.260010
# 2024-02-29  508.079987
#
# [7827 rows x 1 columns]

# %%
spy=spy.reindex(all_days)

# %%
spy
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method='ffill')
# Out:
# /tmp/ipykernel_33/1137873266.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method='ffill')
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  125.750000
# 2011-01-02  125.750000
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  322.859985
# 2019-12-29  322.859985
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01  321.859985
#
# [3289 rows x 1 columns]

# %%
spy.fillna(method='bfill')
# Out:
# /tmp/ipykernel_33/2982224753.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   spy.fillna(method='bfill')
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  127.050003
# 2011-01-02  127.050003
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  321.079987
# 2019-12-29  321.079987
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
spy=yf.download('SPY',interval='1wk') #week interval
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.840673
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.423706
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.211710
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.628662
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.105688
# ...                ...         ...         ...         ...         ...
# 2024-01-29  487.730011  496.049988  482.859985  494.350006  494.350006
# 2024-02-05  493.700012  501.649994  490.230011  501.200012  501.200012
# 2024-02-12  501.170013  503.500000  490.720001  499.510010  499.510010
# 2024-02-19  497.720001  510.130005  493.559998  507.850006  507.850006
# 2024-02-26  508.299988  509.739990  504.750000  508.079987  508.079987
#
#                Volume
# Date
# 1993-01-25    1003200
# 1993-02-01    2234800
# 1993-02-08    1159800
# ...

# %% [markdown]
# # cumulative returns and drawdowns

# %%
import yfinance as yf
apple=yf.download('AAPL')
apple
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099192
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094017
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087117
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089273
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091861
# ...                ...         ...         ...         ...         ...
# 2024-02-23  185.009995  185.039993  182.229996  182.520004  182.520004
# 2024-02-26  182.240005  182.759995  180.649994  181.160004  181.160004
# 2024-02-27  181.100006  183.919998  179.559998  182.630005  182.630005
# 2024-02-28  182.509995  183.119995  180.130005  181.419998  181.419998
# 2024-02-29  181.270004  182.570007  179.529999  180.750000  180.750000
#
#                Volume
# Date
# ...

# %%
apple=apple.Close.to_frame()
apple
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2024-02-23  182.520004
# 2024-02-26  181.160004
# 2024-02-27  182.630005
# 2024-02-28  181.419998
# 2024-02-29  180.750000
#
# [10894 rows x 1 columns]

# %%
import numpy as np
import pandas as pd
apple['d_returns']=np.log(apple.div(apple.shift(1)))
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2024-02-23  182.520004  -0.010085
# 2024-02-26  181.160004  -0.007479
# 2024-02-27  182.630005   0.008082
# 2024-02-28  181.419998  -0.006647
# 2024-02-29  180.750000  -0.003700
#
# [10894 rows x 2 columns]

# %%
apple.dropna(inplace=True)

# %%
apple.d_returns.sum()
# Out:
# 7.250124870558638

# %%
#calculating what u wud receive had u invested in $1 stock in 1980
np.exp(apple.d_returns.sum())
# Out:
# 1408.2806900222163

# %%
apple['cumreturn']=apple.d_returns.cumsum().apply(np.exp)
apple
# Out:
#                  Close  d_returns    cumreturn
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2024-02-23  182.520004  -0.010085  1422.071356
# 2024-02-26  181.160004  -0.007479  1411.475159
# 2024-02-27  182.630005   0.008082  1422.928406
# 2024-02-28  181.419998  -0.006647  1413.500859
# 2024-02-29  180.750000  -0.003700  1408.280690
#
# [10893 rows x 3 columns]

# %% [markdown]
# so had u invested in 1980 ,u wud have received $1422 on 2024-02-23

# %%
import matplotlib.pyplot as plt
apple.cumreturn.plot(figsize=(12,8),title='APPLE BUY AND HOLD',fontsize=12)
plt.show()
#how the returns wud have been till 2025 had u invested in 1980

# %%
apple.d_returns.mean()*252 #16.7% returns per year
# Out:
# 0.16772527929686742

# %%
apple.d_returns.std()*np.sqrt(252) #it varies about 45% high risk
# Out:
# 0.4508698249827459

# %% [markdown]
# # how to calculate drawdowns

# %%
apple['cummamx']=apple.cumreturn.cummax()
apple
# Out:
#                  Close  d_returns    cumreturn      cummamx
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2024-02-23  182.520004  -0.010085  1422.071356  1543.537972
# 2024-02-26  181.160004  -0.007479  1411.475159  1543.537972
# 2024-02-27  182.630005   0.008082  1422.928406  1543.537972
# 2024-02-28  181.419998  -0.006647  1413.500859  1543.537972
# 2024-02-29  180.750000  -0.003700  1408.280690  1543.537972
#
# [10893 rows x 4 columns]

# %%
apple[['cumreturn','cummamx']].plot(figsize=(12,8),title='APPLE BUY AND HOLD',fontsize=12)
plt.show()

# %%
apple['drawdown']=apple['cummamx']-apple['cumreturn']
apple
# Out:
#                  Close  d_returns    cumreturn      cummamx    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2024-02-23  182.520004  -0.010085  1422.071356  1543.537972  121.466616
# 2024-02-26  181.160004  -0.007479  1411.475159  1543.537972  132.062813
# 2024-02-27  182.630005   0.008082  1422.928406  1543.537972  120.609566
# 2024-02-28  181.419998  -0.006647  1413.500859  1543.537972  130.037113
# 2024-02-29  180.750000  -0.003700  1408.280690  1543.537972  135.257282
#
# [10893 rows x 5 columns]

# %% [markdown]
# dollar perspective of drawdown

# %%
apple.drawdown.max()
# Out:
# 444.02718404402026

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index<='2023-01-05 00:00:00')]
# Out:
#                  Close  d_returns    cumreturn      cummamx    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2022-12-29  129.610001   0.027931  1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466  1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122   974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261   984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
apple['drawdown%']=(apple['cummamx']-apple['cumreturn'])/apple['cummamx']

# %%
apple
# Out:
#                  Close  d_returns    cumreturn      cummamx    drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2024-02-23  182.520004  -0.010085  1422.071356  1543.537972  121.466616
# 2024-02-26  181.160004  -0.007479  1411.475159  1543.537972  132.062813
# 2024-02-27  182.630005   0.008082  1422.928406  1543.537972  120.609566
# 2024-02-28  181.419998  -0.006647  1413.500859  1543.537972  130.037113
# 2024-02-29  180.750000  -0.003700  1408.280690  1543.537972  135.257282
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# ...

# %% [markdown]
# percentage perspective of drawdown

# %%
apple['drawdown%'].max() #there was a drawdown of 82% which is super high
# it's the how much an investment or trading account is down from the peak before it recovers back to the peak
# Out:
# 0.82216567924191

# %%
apple['drawdown%'].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
#this took place on 
apple.loc[(apple.index=='1997-12-23 00:00:00')]
# Out:
#                Close  d_returns  cumreturn   cummamx  drawdown  drawdown%
# Date
# 1997-12-23  0.115513   -0.02858   0.899998  5.060882  4.160883   0.822166

# %% [markdown]
# # SMA Strategy

# %%
data=apple.Close.loc[(apple.index>='1997-12-23 00:00:00')]
data
# Out:
# Date
# 1997-12-23      0.115513
# 1997-12-24      0.117188
# 1997-12-26      0.118862
# 1997-12-29      0.117188
# 1997-12-30      0.117746
#                  ...
# 2024-02-23    182.520004
# 2024-02-26    181.160004
# 2024-02-27    182.630005
# 2024-02-28    181.419998
# 2024-02-29    180.750000
# Name: Close, Length: 6588, dtype: float64

# %%
data=data.to_frame()
data
# Out:
#                  Close
# Date
# 1997-12-23    0.115513
# 1997-12-24    0.117188
# 1997-12-26    0.118862
# 1997-12-29    0.117188
# 1997-12-30    0.117746
# ...                ...
# 2024-02-23  182.520004
# 2024-02-26  181.160004
# 2024-02-27  182.630005
# 2024-02-28  181.419998
# 2024-02-29  180.750000
#
# [6588 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data['sma_s']=data.Close.rolling(sma_s).mean()
data['sma_l']=data.Close.rolling(sma_l).mean()
data
# Out:
#                  Close       sma_s     sma_l
# Date
# 1997-12-23    0.115513         NaN       NaN
# 1997-12-24    0.117188         NaN       NaN
# 1997-12-26    0.118862         NaN       NaN
# 1997-12-29    0.117188         NaN       NaN
# 1997-12-30    0.117746         NaN       NaN
# ...                ...         ...       ...
# 2024-02-23  182.520004  188.967200  185.4411
# 2024-02-26  181.160004  188.696200  185.5152
# 2024-02-27  182.630005  188.389600  185.6175
# 2024-02-28  181.419998  188.055800  185.6951
# 2024-02-29  180.750000  187.719399  185.7535
#
# [6588 rows x 3 columns]

# %%
data.plot(figsize=(12,8),title='AAPL - SMA{} | SMA{}'.format(sma_s,sma_l),fontsize=12)
# Out:
# <Axes: title={'center': 'AAPL - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc['2016'].plot(figsize=(12,8),title='AAPL - SMA{} | SMA{}'.format(sma_s,sma_l),fontsize=12)
# Out:
# <Axes: title={'center': 'AAPL - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1998-05-18    0.254464    0.246250    0.207905
# 1998-05-19    0.262277    0.247433    0.209372
# 1998-05-20    0.263951    0.248415    0.210840
# 1998-05-21    0.257813    0.248906    0.212229
# 1998-05-22    0.248884    0.249063    0.213546
# ...                ...         ...         ...
# 2024-02-23  182.520004  188.967200  185.441100
# 2024-02-26  181.160004  188.696200  185.515200
# 2024-02-27  182.630005  188.389600  185.617500
# 2024-02-28  181.419998  188.055800  185.695100
# 2024-02-29  180.750000  187.719399  185.753500
#
# [6489 rows x 3 columns]

# %%
data['position']=np.where(data['sma_s']>data['sma_l'],1,-1)
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1998-05-18    0.254464    0.246250    0.207905         1
# 1998-05-19    0.262277    0.247433    0.209372         1
# 1998-05-20    0.263951    0.248415    0.210840         1
# 1998-05-21    0.257813    0.248906    0.212229         1
# 1998-05-22    0.248884    0.249063    0.213546         1
# ...                ...         ...         ...       ...
# 2024-02-23  182.520004  188.967200  185.441100         1
# 2024-02-26  181.160004  188.696200  185.515200         1
# 2024-02-27  182.630005  188.389600  185.617500         1
# 2024-02-28  181.419998  188.055800  185.695100         1
# 2024-02-29  180.750000  187.719399  185.753500         1
#
# [6489 rows x 4 columns]

# %%
data.loc[:,['sma_s','sma_l','position']].plot(figsize=(12,8),title='AAPL - SMA{} | SMA{}'.format(sma_s,sma_l),fontsize=12)
# Out:
# <Axes: title={'center': 'AAPL - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc[:,['sma_s','sma_l','position']].plot(figsize=(12,8),title='AAPL - SMA{} | SMA{}'.format(sma_s,sma_l),fontsize=12,secondary_y='position')
# Out:
# <Axes: title={'center': 'AAPL - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc['2016',['sma_s','sma_l','position']].plot(figsize=(12,8),title='AAPL - SMA{} | SMA{}'.format(sma_s,sma_l),fontsize=12,secondary_y='position')
# Out:
# <Axes: title={'center': 'AAPL - SMA50 | SMA100'}, xlabel='Date'>

# %%
data['returnsb&h']=np.log(data.Close.div(data.Close.shift(1)))
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h
# Date
# 1998-05-18    0.254464    0.246250    0.207905         1         NaN
# 1998-05-19    0.262277    0.247433    0.209372         1    0.030242
# 1998-05-20    0.263951    0.248415    0.210840         1    0.006362
# 1998-05-21    0.257813    0.248906    0.212229         1   -0.023529
# 1998-05-22    0.248884    0.249063    0.213546         1   -0.035248
# ...                ...         ...         ...       ...         ...
# 2024-02-23  182.520004  188.967200  185.441100         1   -0.010085
# 2024-02-26  181.160004  188.696200  185.515200         1   -0.007479
# 2024-02-27  182.630005  188.389600  185.617500         1    0.008082
# 2024-02-28  181.419998  188.055800  185.695100         1   -0.006647
# 2024-02-29  180.750000  187.719399  185.753500         1   -0.003700
#
# [6489 rows x 5 columns]

# %%
data['strategy']=data['returnsb&h']*data.position.shift(1)
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1998-05-18    0.254464    0.246250    0.207905         1         NaN       NaN
# 1998-05-19    0.262277    0.247433    0.209372         1    0.030242  0.030242
# 1998-05-20    0.263951    0.248415    0.210840         1    0.006362  0.006362
# 1998-05-21    0.257813    0.248906    0.212229         1   -0.023529 -0.023529
# 1998-05-22    0.248884    0.249063    0.213546         1   -0.035248 -0.035248
# ...                ...         ...         ...       ...         ...       ...
# 2024-02-23  182.520004  188.967200  185.441100         1   -0.010085 -0.010085
# 2024-02-26  181.160004  188.696200  185.515200         1   -0.007479 -0.007479
# 2024-02-27  182.630005  188.389600  185.617500         1    0.008082  0.008082
# 2024-02-28  181.419998  188.055800  185.695100         1   -0.006647 -0.006647
# 2024-02-29  180.750000  187.719399  185.753500         1   -0.003700 -0.003700
#
# ...

# %%
data.dropna(inplace=True)

# %% [markdown]
# b&h -> buy and hold

# %%
data[['returnsb&h','strategy']].sum()
# Out:
# returnsb&h    6.565711
# strategy      2.376398
# dtype: float64

# %% [markdown]
# need to look at few more factors

# %%
data[['returnsb&h','strategy']].sum().apply(np.exp)
#shows what $1 investment will look like
# Out:
# returnsb&h    710.316586
# strategy       10.766053
# dtype: float64

# %%
data[['returnsb&h','strategy']].std()*np.sqrt(252)
#its similar
# Out:
# returnsb&h    0.419481
# strategy      0.419748
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # strategy adjusted with long bias (removing going short)

# %%
data['position2']=np.where(data['sma_s']>data['sma_l'],1,0)
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  \
# Date
# 1998-05-19    0.262277    0.247433    0.209372         1    0.030242
# 1998-05-20    0.263951    0.248415    0.210840         1    0.006362
# 1998-05-21    0.257813    0.248906    0.212229         1   -0.023529
# 1998-05-22    0.248884    0.249063    0.213546         1   -0.035248
# 1998-05-26    0.238281    0.248984    0.214752         1   -0.043536
# ...                ...         ...         ...       ...         ...
# 2024-02-23  182.520004  188.967200  185.441100         1   -0.010085
# 2024-02-26  181.160004  188.696200  185.515200         1   -0.007479
# 2024-02-27  182.630005  188.389600  185.617500         1    0.008082
# 2024-02-28  181.419998  188.055800  185.695100         1   -0.006647
# 2024-02-29  180.750000  187.719399  185.753500         1   -0.003700
#
#             strategy  position2
# Date
# 1998-05-19  0.030242          1
# 1998-05-20  0.006362          1
# ...

# %%
data['strategy2']=data['returnsb&h']*data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  \
# Date
# 1998-05-20    0.263951    0.248415    0.210840         1    0.006362
# 1998-05-21    0.257813    0.248906    0.212229         1   -0.023529
# 1998-05-22    0.248884    0.249063    0.213546         1   -0.035248
# 1998-05-26    0.238281    0.248984    0.214752         1   -0.043536
# 1998-05-27    0.238839    0.248996    0.215968         1    0.002339
# ...                ...         ...         ...       ...         ...
# 2024-02-23  182.520004  188.967200  185.441100         1   -0.010085
# 2024-02-26  181.160004  188.696200  185.515200         1   -0.007479
# 2024-02-27  182.630005  188.389600  185.617500         1    0.008082
# 2024-02-28  181.419998  188.055800  185.695100         1   -0.006647
# 2024-02-29  180.750000  187.719399  185.753500         1   -0.003700
#
#             strategy  position2  strategy2
# Date
# 1998-05-20  0.006362          1   0.006362
# ...

# %%
data[['returnsb&h','strategy2']].sum()
# Out:
# returnsb&h    6.535469
# strategy2     4.440813
# dtype: float64

# %%
data[['returnsb&h','strategy2']].sum().apply(np.exp)
# Out:
# returnsb&h    689.156865
# strategy2      84.843851
# dtype: float64

# %%
data[['returnsb&h','strategy2']].std()*np.sqrt(252)
# Out:
# returnsb&h    0.419474
# strategy2     0.346325
# dtype: float64

# %% [markdown]
# strategy2 performs better than strategy1

# %%
data[['strategy','strategy2']].std()*np.sqrt(252)
# Out:
# strategy     0.419739
# strategy2    0.346325
# dtype: float64

# %% [markdown]
# creating function

# %%
def test_strategy(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)
    data=df.Close.to_frame()
    data['returns']=np.log(data.Close.div(data.Close.shift(1)))
    data['SMA_S']=data.Close.rolling(int(SMA[0])).mean()
    data['SMA_L']=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    data['position']=np.where(data['SMA_S']>data['SMA_L'],1,-1)
    data['strategy']=data['returns']*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data['strategy'].sum())
    std=data['strategy'].std()*np.sqrt(252)
    return ret,std

# %%
test_strategy('MSFT','2000-01-01','2020-01-01',(50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (0.39097954932295986, 0.2906766831415829)

# %% [markdown]
# 1 dollar gives u 0.39% return with 0.29% risk

# %%
test_strategy('AAPL','2000-01-01','2020-01-01',(50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (16.540320732436786, 0.36699682903803943)

# %% [markdown]
# 16.54 is like 6.54 times of 1 dollar inc

# %%
test_strategy('TSLA','2000-01-01','2020-01-01',(50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (1.3908153866370587, 0.4956456904999671)

# %%
test_strategy('SPY','2000-01-01','2020-01-01',(50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (4.766371508372407, 0.18787947185958592)

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S,SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()
        
    def get_data(self):
        df=yf.download(self.symbol,start=self.start,end=self.end)
        data=df.Close.to_frame()
        data['returns']=np.log(data.Close.div(data.Close.shift(1)))
        data['SMA_S']=data.Close.rolling(int(self.SMA_S)).mean()
        data['SMA_L']=data.Close.rolling(int(self.SMA_L)).mean()
        data.dropna(inplace=True)
        self.data2=data
        return data
    
    def test_results(self):
        data=self.data2.copy().dropna()
        data['position']=np.where(data['SMA_S']>data['SMA_L'],1,-1)
        data['strategy']=data['returns']*data.position.shift(1)
        data.dropna(inplace=True)
        data['returnsbh']=data['returns'].cumsum().apply(np.exp)
        data['returnstrategy']=data['strategy'].cumsum().apply(np.exp)
        perf=data['returnstrategy'].iloc[-1]
        outperf=perf-data['returnsbh'].iloc[-1]
        
        self.results=data
        ret=np.exp(data['strategy'].sum())
        std=data['strategy'].std()*np.sqrt(252)
#         return ret,std
        return round(perf,6),round(outperf,6)
    
    def plot_results(self):
        if self.results is None:
            print('Run the test')
        else:
            title='{}| SMA_S={} | SMA_L{}'.format(self.symbol,self.SMA_S,self.SMA_L)
            self.results[['returnsbh','returnstrategy']].plot(title=title,figsize=(12,8))

# %%
tester=SMABacktester('AAPL',1,200,'2000-01-01','2020-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (239.027886, 47.814157)

# %%
tester.plot_results()
